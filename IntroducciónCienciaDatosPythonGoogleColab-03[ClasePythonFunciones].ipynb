# %% [markdown]
# ---
#
# <div align="left">
# <p><img alt="IUDigital" height="140px" src="https://www.iudigital.edu.co/Style%20Library/images/logo-escudo.png" align="left" hspace="10px" vspace="0px"></p></div>
# <div> </div>
# <div align="right">
# <p><img alt="Posgrado" height="140px" src="https://www.iudigital.edu.co/OfertaEducativa/PublishingImages/Paginas/Especializacion-En-Analitica-y-Big-Data/Big-Data.jpg" align="right" hspace="10px" vspace="10px"></p></div>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <p>
# <h1> <b> Introducción a Ciencia de Datos con Python y Google Colab </b> </h1>
# <hr size=10 noshade color="red">
# </p>
# <p>
# <img alt="CC" height="70px" src="https://creativecommons.org/images/deed/cc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="Attribution" height="70px" src="https://creativecommons.org/images/deed/attribution_icon_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="NC" height="70px" src="https://creativecommons.org/images/deed/nc_blue_x2.png" align="left" hspace="0px" vspace="0px">
# <img alt="SA" height="70px" src="https://creativecommons.org/images/deed/sa_blue_x2.png" align="left" hspace="0px" vspace="0px">
# </p>
#
# <div align="right">
# <h1> <b> Por: Julián Andrés Castillo | M.Sc.</b> </h1>
# <h2> Profesor Ocasional </h2>
# <strong><a href="mailto:julian.castillo@iudigital.edu.co"> ✉ Julian Andres Castillo Grisales [ julian.castillo@iudigital.edu.co ]</a></strong>
# </div>
#
# <br>
#
# **El presente curso hace parte del Posgrado en Programación Aplicada y los semestres cinco y seis de la Tecnología en Desarrollo de Software de la Institución Universitaria Digital de Antioquia.**
#
# ---

# %% [markdown]
# <p><a name="contents"></a></p>
#
# # **Contenido Sesión 3 - Funciones**
#
# - <a href="#s1">01. Funciones</a><br>
# - <a href="#s2">02. Importancia de las funciones en Python</a><br>
# - <a href="#s3">03. Llamadas a funciones y definición</a><br>
# - <a href="#s4">04. Argumentos</a><br>
# - <a href="#s5">05. La instruccion `return`</a><br>
# - <a href="#s6">06. Ejercicios</a><br>
# - <a href="#s7">07. Clases y Objetos</a><br>
#
# El presente documento está basado en los siguientes librosy documentos:
#
# *   Python Website. (2021). Python 3.9.1 documentation. Retrieved February 03, 2021, from https://docs.python.org/
# *   W3schools.com. (2021). Python tutorial. Retrieved February 04, 2021, from https://www.w3schools.com/python/default.asp
# *   Martelli, A., Ravenscroft, A., & Ascher, D. (2005). Python cookbook. " O'Reilly
# *   VanderPlas, J. (2016). Python data science handbook: Essential tools for working with data. " O'Reilly Media, Inc.".
# *   realpython.com. (2021). Real Python Tutorials. Retrieved February 04, 2021, from https://realpython.com/
# *   Sweigart, A. (2019). Automate the boring stuff with Python: practical programming for total beginners. No Starch Press.
# *   Ziadé, T. (2008). Expert Python Programming. Packt Publishing Ltd.
# *   Pilgrim, M., & Willison, S. (2009). Dive Into Python 3 (Vol. 2). Apress.
# *   Cairo, B. (2005). Metodología de la Programación: Algoritmos, diagramas de flujo y programas. Alfaomega.
# </p>
#
# [[Contenidos]](#contents)

# %% [markdown]
# <p><a name="s1"></a></p>
#
# # **01. Funciones**
# [[Contenidos]](#contents)

# %% [markdown]
# ##**Definicion de Función**
# <p>
#
# A día de hoy es posible que esté familiarizado con el concepto matemático de una función. Una función es una relación o mapeo entre una o más entradas y un conjunto de salidas. En matemáticas, una función normalmente se representa así:
#
# <center>
#
# $f(x) = x$
#
# </center>
#
# Las funciones en los algoritmos tienen a representar como se expresa previamente como una relación entre una o más entradas a lo cual se podría interpretar de la siguiente manera:
# <center>
# <img alt="Funcion" height="40px" src="https://files.realpython.com/media/t.74ec5430f457.png" align="center" hspace="10px" vspace="0px">
# </center>
#
# Aquí, $f$ es una función que opera en las entradas $x$ e $y$. La salida de la función es $z$. Sin embargo, las funciones de programación son mucho más generalizadas y versátiles que esta definición matemática. De hecho, la definición y el uso adecuados de las funciones son tan importantes para el desarrollo de software que prácticamente todos los lenguajes de programación modernos admiten funciones integradas y definidas por el usuario.
#
# En programación, una función es un bloque de código autónomo que encapsula una tarea específica o un grupo de tareas relacionadas. En Colabs previos hemos visto dicha funcionalidad en las llamadas `Built-in Functions` que ya hemos utilizado como:
#
#
# *   `len()`
# *   `print()`
# *   `abs()`
# *   `help()`
# *   `input()`
# *   `sum()`
# *   `range()`
#
# Entre otras, clic [aquí](https://docs.python.org/3/library/functions.html#built-in-functions) para acceder a la lista de ellas.
#
# Veamos el siguiente ejemplo:
#
# </p>

# %%
a = ['posicion0', 'posicion1', 'posicion2']
print(len(a))

# %% [markdown]
# ##**Argumentos y retorno de una función, ejemplo con `print()` y `len()`**
# La variable `a` es una lista que contiene 3 textos de los cuales usamos las funciones `print()` y `len()` para realizar acciones, el código donde se realizan dichas acciones está incorporado en Python y no es necesario saber dónde se encuentra, es necesario conocer su funcionalidad y los parámetros o argumentos que necesita para ejecutarse.
# Para el caso de `print()` y `len()` detallaremos los parámetros y resultados.
#
#
#
# >*   `print()`
# >>*   Argumentos: variables, texto, datos entre otros (objetos).
# >>*   Retorna: texto en consola en donde muestra los valores evaluados de los argumentos
# >
# >*   `len()`
# >>*   Argumentos: secuencias, objetos iterables.
# >>*   Retorna: Devuelve la longitud (el número de elementos) de un objeto.
#
# Cuando definimos nuestra propia función de Python, funciona igual. Desde algún lugar de nuestro código, llamará la función de Python y la ejecución del programa se transferirá al cuerpo del código que forma la función.
#
# Cuando finaliza la función, la ejecución vuelve a la ubicación donde se llamó a la función. Dependiendo de cómo diseñó la secuencia de la función, los datos pueden pasarse cuando se llama a la función y los valores devueltos pueden devolverse cuando finaliza.

# %% [markdown]
# <p><a name="s2"></a></p>
#
# # **02. Importancia de las funciones en Python**
# [[Contenidos]](#contents)
#
# Prácticamente todos los lenguajes de programación que se utilizan hoy en día admiten una forma de funciones definidas por el usuario, aunque no siempre se denominan funciones. En otros idiomas, es posible que se mencionen como uno de los siguientes:
#
#
# *   Subrutinas
# *   Procedimientos
# *   Métodos
# *   Subprogramas

# %% [markdown]
# ## **Abstracción y reutilización**
# <p>
#
# Suponga que escribe un código que hace algo útil. A medida que continúe con el desarrollo, encontrará que la tarea realizada por ese código es una que necesita con frecuencia, en muchas ubicaciones diferentes dentro de su aplicación. ¿Qué deberías hacer? Bueno, podría simplemente replicar el código una y otra vez, utilizando la capacidad de copiar y pegar de su editor.
#
# Más adelante, probablemente decida que es necesario modificar el código en cuestión. O encontrará algo malo en él que necesita ser arreglado, o querrá mejorarlo de alguna manera. Si hay copias del código esparcidas por toda su aplicación, deberá realizar los cambios necesarios en cada ubicación.
#
# *Nota: A primera vista, puede parecer una solución razonable, pero a largo plazo, es probable que se convierta en una pesadilla de mantenimiento. Si bien su editor de código puede ayudar al proporcionar una función de búsqueda y reemplazo, este método es propenso a errores y podría introducir fácilmente errores en su código que serán difíciles de encontrar.*
#
# Una mejor solución es definir una función de Python que realice la tarea. En cualquier lugar de su aplicación que necesite realizar la tarea, simplemente llame a la función. Más adelante, si decide cambiar cómo funciona, solo necesita cambiar el código en una ubicación, que es el lugar donde se define la función. Los cambios se recogerán automáticamente en cualquier lugar donde se llame a la función.
#
# La abstracción de la funcionalidad en una definición de función es un ejemplo del principio de desarrollo de software *Don’t Repeat Yourself* (DRY). Esta es posiblemente la motivación más fuerte para usar funciones.

# %% [markdown]
# ## **Modularidad**
#
# Las funciones permiten dividir procesos complejos en pasos más pequeños. Imagine, por ejemplo, que tiene un programa que lee un archivo, procesa el contenido del archivo y luego escribe un archivo de salida. Su código podría verse así:
#
#
# ```python
# # Programa principal
# # Código para leer un archivo
# <statement>
# <statement>
# <statement>
# <statement>
#
# # Código para procesar el archivo
# <statement>
# <statement>
# <statement>
# <statement>
#
# # Código para imprimir el archivo procesado
# <statement>
# <statement>
# <statement>
# <statement>
# ```
# En este ejemplo, el programa principal es un montón de código encadenado en una secuencia larga, con espacios en blanco y comentarios para ayudar a organizarlo. Sin embargo, si el código se volviera mucho más largo y complejo, entonces le resultaría cada vez más difícil entenderlo.
#
# Alternativamente, puede estructurar el código de la siguiente manera:
#
#
#
# ```python
# def read_file():
#     # Código para leer un archivo
#     <statement>
#     <statement>
#     <statement>
#     <statement>
#
# def process_file():
#     # Código para procesar el archivo
#     <statement>
#     <statement>
#     <statement>
#     <statement>
#
# def write_file():
#     # Código para imprimir el archivo procesado
#     <statement>
#     <statement>
#     <statement>
#     <statement>
#
#
# # Programa principal
# read_file()
# process_file()
# write_file()
# ```
# Este ejemplo está modularizado. En lugar de encadenar todo el código, se divide en funciones separadas, cada una de las cuales se centra en una tarea específica. Esas tareas son leer, procesar e imprimir. El programa principal ahora simplemente necesita llamar a cada uno de estos a su vez.
#
# *Nota: La palabra clave `def` introduce una nueva definición de función de Python.*

# %% [markdown]
# ## **Tareas del día a día que pueden replicarse**
#
# Si tuviéramos que detallar una actividad a realizar secuencialmente que pudiera implementar diariamente ¿cuál relacionarías con una función y por qué?
# Ejemplo:
# *   Detallar el transporte diario al trabajo.

# %% [markdown]
# <p><a name="s3"></a></p>
#
# # **03. Llamadas a funciones y definición**
# [[Contenidos]](#contents)

# %% [markdown]
# ## **Sintaxis de una función**
#
# La sintaxis habitual para definir una función de Python es la siguiente:
#
#
# ```python
# def <nombre_funcion>([<argumentos_parametros>]):
#     <instrucciones>
# ```
#
# **Componente**|**Detalle**
# ---|---
# `def`|La palabra clave que informa a Python de que se está definiendo una función.
# `<nombre_funcion>`|Un identificador de Python válido que nombra la función
# `<argumentos_parametros>`|Una lista opcional de parámetros separados por comas que se pueden pasar a la función
# `:`|Puntuación que denota el final del encabezado de la función de Python (el nombre y la lista de parámetros)
# `<instrucciones>`|Un bloque de instrucciones validas de Python
#
# El elemento final, `<instrucciones>`, se denomina cuerpo de la función. El cuerpo es un bloque de declaraciones que se ejecutarán cuando se llame a la función. El cuerpo de una función de Python se define mediante sangría de acuerdo con [la regla de fuera de juego](https://en.wikipedia.org/wiki/Off-side_rule). Esto es lo mismo que los bloques de código asociados con una estructura de control, como una instrucción `if` o `while`.
#
# La sintaxis para llamar a una función de Python es la siguiente:
#
# ```python
# <nombre_funcion>([<argumentos_parametros>])
# ```
#
# `<argumentos_parametros>` son los valores pasados a la función. Corresponden a los parámetros en la definición de la función de Python. Se puede definir una función que no tome ningún argumento, pero los paréntesis aún son obligatorios. Tanto una definición de función como una llamada a función siempre deben incluir paréntesis, incluso si están vacíos.
#
# Ejemplo:
#
#
# ```python
# def f():
#     s = 'en la función f()'
#     print(s)
#
# print('Antes de llamar a f()')
# f()
# print('Después de llamar a f()')
# ```

# %%
def f():
    s = 'en la función f()'
    print(s)

print('Antes de llamar a f()')
f()
print('Después de llamar a f()')

# %% [markdown]
# ## **Detalle del código**
#
# **La línea 1** usa la palabra clave `def` para indicar que se está definiendo una función. La ejecución de la declaración `def` simplemente crea la definición de `f()`. Todas las siguientes líneas que están sangradas (**líneas 2 a 3**) pasan a formar parte del cuerpo de `f()` y se almacenan como su definición, pero aún no se ejecutan.
#
# La **línea 4** es un espacio en blanco entre la definición de la función y la primera línea del programa principal. Si bien no es sintácticamente necesario, es bueno tenerlo.
#
# **La línea 5** es la primera declaración que no tiene sangría porque no forma parte de la definición de `f()`. Es el comienzo del programa principal. Cuando se ejecuta el programa principal, esta instrucción se ejecuta primero.
#
# **La línea 6** es una llamada a `f()`. Tenga en cuenta que siempre se requieren paréntesis vacíos tanto en una definición de función como en una llamada de función, incluso cuando no hay parámetros ni argumentos. La ejecución procede a `f()` y se ejecutan las declaraciones en el cuerpo de `f()`.
#
# La **línea 7** es la siguiente línea que se ejecutará una vez que haya terminado el cuerpo de `f()`. La ejecución vuelve a esta declaración `print()`.
# |
# La secuencia de ejecución (o flujo de control) de la celda anterior se muestra en el siguiente diagrama:
#
# <center>
# <img alt="Funcion" height="400px" src="https://i.imgur.com/ui887QO.png" align="center" hspace="100px" vspace="0px">
# </center>

# %% [markdown]
# ### **Función vacía**
#
# Es posible definir una función vacía que no hace nada. Esto se conoce como [`stub`](https://es.wikipedia.org/wiki/Stub), que suele ser un marcador de posición temporal para una función de Python que se implementará por completo en un momento posterior. Así como un bloque en una estructura de control no puede estar vacío, tampoco el cuerpo de una función. Para definir una función stub, use la sentencia: `pass`
#
# ```python
# def f():
#     pass
# f()
# ```
# Como puede ver , una llamada a una función stub es sintácticamente válida pero no hace nada.

# %% [markdown]
# ## **Ejemplos de Funciones**
#
# ### **Ejercicio 1**
# Definir una función que imprima la hora actual usando [pytz](https://pypi.org/project/pytz/) con base en la [TZ_Database](https://es.wikipedia.org/wiki/TZ_Database).

# %%
from datetime import datetime
import pytz # pytz PythonTimeZone utiliza la Base de Datos de zonas https://es.wikipedia.org/wiki/TZ_Database

def HoraColombiana():
    bogota = pytz.timezone('America/Bogota') 
    fechahora = datetime.now(bogota)
    print("Hora Colombiana:", fechahora.strftime("%H:%M:%S:%p")) #Hora 24horas
    print("Hora Colombiana:", fechahora.strftime('%Y/%m/%d %I:%M:%S %p')) #Hora 12 Horas mas fecha

HoraColombiana()

# %% [markdown]
# ### **Ejercicio 2**
# Definir una función que imprima datos relacionados con el sistema operativo.

# %%
import platform
import sys
def ImprimirDetallesSistema():
    print(sys.version)
    print(platform.system())
    print(platform.machine())
    print(platform.platform())
    print(platform.version())
ImprimirDetallesSistema()

# %% [markdown]
# <p><a name="s4"></a></p>
#
# # **04. Argumentos**
# [[Contenidos]](#contents)

# %% [markdown]
# ## **Paso de Argumentos**
# Hasta ahora las funciones que hemos definido no han tomado ningún argumento. Eso a veces puede ser útil y ocasionalmente escribirás tales funciones. Sin embargo, más a menudo querrá pasar datos a una función para que su comportamiento pueda variar de una invocación a la siguiente.

# %% [markdown]
# ## **Argumentos posicionales**
# La forma más sencilla de pasar argumentos a una función de Python es con argumentos posicionales (argumentos obligatorios). En la definición de la función, se especifica una lista de parámetros separados por comas entre los paréntesis:
#
# ```python
# def f(cantidad, articulo, precio):
#     print(f'{cantidad} {articulo} cuesta ${precio:.2f}')
# ```
# Cuando se llama a la función, se especifica una lista correspondiente de argumentos:
#
# ```python
# f(1,'Docena Huevos',1800)
# > 1 Docena Huevos cuesta $1800.00
# ```
#
# Los parámetros (cantidad, artículo y precio) se comportan como variables que se definen localmente para la función. Cuando se llama a la función, los argumentos que se pasan (1,'Docena Huevos',1800) están vinculados a los parámetros en orden, como por asignación de variable:
#
# Parametro | Argumento
# ---|---
# `cantidad`|<center>`1`
# `articulo`|<center>`'Docena Huevos'`
# `precio`|<center>`1800`
#
# En algunos textos de programación, los parámetros dados en la definición de la función se denominan parámetros formales y los argumentos en la llamada a la función se denominan parámetros reales:
#
# <center>
# <img alt="Funcion" src="https://raw.githubusercontent.com/juliancastillo-iudigital/FundamentosProgramacionPosgrados2021-1/main/ArgumentosFunciones.png" align="center" hspace="100px" vspace="0px">
# </center>
#
# Aunque los argumentos posicionales son la forma más sencilla de pasar datos a una función, también ofrecen la menor flexibilidad. Para empezar, el orden de los argumentos en la llamada debe coincidir con el orden de los parámetros en la definición. No hay nada que le impida especificar argumentos posicionales fuera de orden, excepto ingresar de forma incorrecta los parámetros.
# Con argumentos posicionales, los argumentos en la llamada y los parámetros en la definición deben coincidir no solo en orden sino también en número. Esa es la razón por la que los argumentos posicionales también se denominan argumentos obligatorios.

# %%
def f(cantidad, articulo, precio):
    print(f'{cantidad} {articulo} cuesta ${precio:,.0f}')

f(1,'Docena Huevos',1800)

# %% [markdown]
# ## **Argumentos tipo `Keyword`**
# Cuando llama a una función, puede especificar argumentos en la forma `<keyword> = <valor>`. En ese caso, cada `<keyword>` debe coincidir con un parámetro en la definición de función de Python. Por ejemplo, la función `f()` definida previamente se puede llamar con argumentos de palabras clave de la siguiente manera:
#
#
# ```python
# f(cantidad=1,articulo='Docena Huevos',precio=1800)
# > 1 Docena Huevos cuesta $1800.00
# ```
# Hacer referencia a una palabra clave que no coincide con ninguno de los parámetros declarados genera una excepción:
#
# ```python
# f(cantidad=1,articulo='Docena Huevos',valor=1800)
#
# TypeError: f() got an unexpected keyword argument 'valor'
# ```
# El uso de argumentos con `keyword` elimina la restricción en el orden de los argumentos. Cada argumento `keyword` designa explícitamente un parámetro específico por nombre, por lo que puede especificarlos en cualquier orden y Python aún sabrá qué argumento va con qué parámetro y sin embargo, al igual que con los argumentos posicionales, el número de argumentos y parámetros debe coincidir:

# %% [markdown]
# ## **Argumentos Opcionales**
# Si un parámetro especificado en una definición de función de Python tiene la forma `<nombre> = <valor>`, entonces `<valor>` se convierte en un valor predeterminado para ese parámetro. Los parámetros definidos de esta manera se denominan parámetros predeterminados u opcionales. A continuación se muestra un ejemplo de una definición de función con parámetros opcionales:
#
#
# ```python
# def f(cantidad=1, articulo='docena', precio=1800):
#     print(f'{cantidad} {articulo} cuesta ${precio:.2f}')
# ```
# Cuando se llama a esta versión de `f()`, cualquier argumento que quede fuera asume su valor predeterminado:
#
#
# ```python
# f()
# > 1 docena cuesta $1800.00
# f(1, 'Empanada', 500)
# > 1 Empanada cuesta $500.00
# f('Empanada', 500)
# > Empanada 500 cuesta $1800.00
# f(1, 'Empanada')
# > 1 Empanada cuesta $1800.00
# f(1)
# > 1 docena cuesta $1800.00
# f(articulo='buñuelo')
# > 1 buñuelo cuesta $1800.00
# ```

# %%
def f(cantidad=1, articulo='docena', precio=1800):
    print(f'{cantidad} {articulo} cuesta ${precio:.2f}')

# %%
f()    
f(1, 'Empanada', 500)
f('Empanada', 500)
f(1, 'Empanada')
f(1)
f(articulo='buñuelo')

# %% [markdown]
# En resumen:
# *   Los argumentos posicionales deben coincidir en orden y número con los parámetros declarados en la definición de la función.
# *   Los parámetros predeterminados permiten omitir algunos argumentos cuando se llama a la función, pero su orden afecta su omisión.

# %% [markdown]
# <p><a name="s5"></a></p>
#
# # **05. La instruccion `return`**
# [[Contenidos]](#contents)
#
# ¿Cuál es la finalidad que debe tener una función?, ¿qué debe hacer una función de Python? Hasta el momento las funciones de Python son repositorios que describen una acción, reciben parámetros pero pueden hacer mucho más.
# Después de todo, en muchos casos, si una función no causa algún cambio en el entorno de llamada, entonces no tiene mucho sentido llamarla. ¿Cómo debería afectar una función su solicitud o petición?
#
# Python utiliza la posibilidad de usar valores de retorno en funciones. Una declaración de retorno en una función de Python tiene dos propósitos:
#
# 1. Inmediatamente termina la función y devuelve el control de ejecución a la llamada.
# 2. Proporciona un mecanismo mediante el cual la función puede devolver datos a la persona o instrucción que llama la función.

# %% [markdown]
# ## **Saliendo de una Función**
# En una función, una declaración de retorno (`return`) provoca la salida inmediata de la función de Python y la transferencia de la ejecución a la línea de la llamada a la función.
#
#
# ```python
# def f():
#     print('Arroz')
#     print('Yuca')
#     return
#
# f()
# >Arroz
# >Yuca
# ```
# En este ejemplo, la declaración de retorno es realmente superflua. Una función volverá a la llamada cuando caiga al final, es decir, después de que se ejecute la última instrucción del cuerpo de la función. Entonces, esta función se comportaría de manera idéntica sin la declaración de retorno.
#
# Sin embargo, no es necesario que las declaraciones de devolución estén al final de una función. Pueden aparecer en cualquier parte de un cuerpo  e incluso varias veces. Considere este ejemplo:
#
#
#
# ```python
# def f(x):
#     if x < 0:
#         return
#     if x > 100:
#         return
#     print(x)
# f(-3)
# f(105)
# f(64)
# >64
# ```
# Las dos primeras llamadas a `f()` no generan ningún resultado, porque se ejecuta una instrucción de retorno y la función sale prematuramente, antes de que se alcance la instrucción `print()` en la línea 6.
#
# Este tipo de paradigma puede ser útil para verificar errores en una función. Puede verificar varias condiciones de error al comienzo de la función, con declaraciones de retorno que salen de la función si hay un problema como en el siguiente caso:
#
#
# ```python
# def f():
#     if error_cond1:
#         return
#     if error_cond2:
#         return
#     if error_cond3:
#         return
#
#     <proceso normal de la funcion>
# ```
#
# Si no se encuentra ninguna de las condiciones de error, la función puede continuar con su procesamiento normal.

# %%
def f(x):
    if x < 0:
        return
    if x > 100:
        return
    print(x)
f(-3)
f(105)
f(64)

# %% [markdown]
# ## **Retornar datos**
# Además de salir de una función, la declaración `return` también se usa para devolver datos al llamado de la función. Si una declaración de retorno dentro de una función de Python va seguida de una expresión, en el entorno de llamada, la llamada a la función se evalúa como el valor de esa expresión:
#
#
# ```python
# def f():
#     return 'Tamal'
# s = f()
# print(s)
# 'Tamal'
# ```
# Aquí, el valor de la expresión `f()` en la línea 3 es 'Tamal', que se asigna a la variable `s`.
#
# Una función puede devolver cualquier tipo de objeto. En Python, eso significa prácticamente cualquier cosa. En el entorno de llamada, la ejecución de la función se puede utilizar sintácticamente de cualquier forma que tenga sentido para el tipo de objeto que devuelve la función.
#
# Por ejemplo, en este código, `f()` devuelve un diccionario. Entonces, en el entorno de llamada, la expresión `f()` representa un diccionario, y `f()['c']` es una referencia clave válida en ese diccionario:
#
#
# ```python
# def f():
#     return dict(a=1, b=2, c=3)
# f()
# {'a': 1, 'b': 2, 'c': 3}
# f()['c']
# ```
# En el siguiente ejemplo, `f()` devuelve una cadena que se puede dividir como cualquier otra cadena:
#
# ```python
# def f():
#     return 'empanadas'
# f()[4:8]
# ```
# Aquí, `f()` devuelve una lista que se puede indexar o dividir:
#
# ```python
# def f():
#     return ['Arroz', 'Papa', 'Yuca', 'Platano']
#
# print(f())
# > ['Arroz', 'Papa', 'Yuca', 'Platano']
# print(f()[2])
# > Yuca
# print(f()[::-1])
# > ['Platano', 'Yuca', 'Papa', 'Arroz']
# ```
#
# Si se especifican varias expresiones separadas por comas en una declaración `return`, se empaquetan y se devuelven como una tupla:
#
# ```python
# def f():
#     return 'Arroz', 'Papa', 'Yuca', 'Platano'
#
# print(type(f()))
# t = f()
# > <class 'tuple'>
# print(t)
# > ('Arroz', 'Papa', 'Yuca', 'Platano')
# a, b, c, d = f()
# print(f'a = {a}, b = {b}, c = {c}, d = {d}')
# > a = Arroz, b = Papa, c = Yuca, d = Platano
# ```
#
# Cuando no se proporciona ningún valor de retorno en una función de Python, esta devuelve el valor especial de Python `None`, adicionalmente pasa lo mismo si el cuerpo de la función no contiene una declaración de retorno y la función llega al final.
#
# ```python
# def f():
#     return
# print(f())
# None
# ```
# ```python
# def f():
#     pass
# print(f())
# None
# ```
# Nota: `None` es falso evaluado en un contexto booleano.

# %%
def f():
    return 'Tamal'
s = f()
print(s)

# %%
def f():
    return dict(a=1, b=2, c=3)
f()
{'a': 1, 'b': 2, 'c': 3}
f()['c']

# %%
def f():
    return 'empanadas'
f()[4:8]

# %%
def f():
    return ['Arroz', 'Papa', 'Yuca', 'Platano']
 
print(f())
print(f()[2])
print(f()[::-1])

# %%
def f():
    return 'Arroz', 'Papa', 'Yuca', 'Platano'
 
print(type(f()))
t = f()
print(t)
a, b, c, d = f()
print(f'a = {a}, b = {b}, c = {c}, d = {d}')

# %%
def f():
    return
print(f())
None

# %%
def f():
    pass
print(f())
None

# %% [markdown]
# <p><a name="s6"></a></p>
#
# # **06. Ejercicios**
# [[Contenidos]](#contents)

# %% [markdown]
# ### Ejercicio 1
#
# Realizar una función que permita ingresar la calificación de un estudiante, si la nota es mayor o igual a 3 imprimir aprobado.
#
# Nivel de dificultad:★☆☆☆☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def ClasificadorNotas(nota):
#     if nota >= 3:
#         print('Ganó')
#     else:
#         print('Perdió')
#
# nota = float(int(input('Ingresar la nota: ')))
# ClasificadorNotas(nota)
#
# --->

# %%
#Solución

# %% [markdown]
# ### Ejercicio 2
#
# Realizar una función que permita detallar si una nota se encuentra bien categorizada, es decir, que la nota sea superior o igual a cero y menor o igual a cinco y retornar `True` si es correcto y `False` si no es correcto.
#
# Nivel de dificultad:★★☆☆☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def ValidadorNotas(nota):
#     if nota >= 0 and nota <= 5:
#         return True
#     else:
#         return False
#
# nota = float(int(input('Ingresar la nota: ')))
# ValidadorNotas(nota) #Notese que no imprime nada
# print(ValidadorNotas(nota)) #Ahora si imprime
#
#
# --->

# %%
#Solución

# %% [markdown]
# ### Ejercicio 3
#
# Realizar un algoritmo que permita utilizar las dos funciones previas para clasificar una nota y su validez.
#
# Nivel de dificultad:★★☆☆☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# nota = float(int(input('Ingresar la nota: ')))
#
# if ValidadorNotas(nota):
#     ClasificadorNotas(nota)
# else:
#     print('Nota Invalida, favor revisar.')
#
# --->

# %%
#Solución

# %% [markdown]
# ### Ejercicio 4
#
# Crear una función que reciba dos argumentos el nombre y la edad de una persona e imprima los valores.
#
# Nivel de dificultad:★☆☆☆☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def NombreEdad(nombre, edad):
#     print(nombre, edad)
#
# NombreEdad("Bruce Wayne", 25)
#
#
# --->

# %%
#Solución

# %% [markdown]
# ### Ejercicio 5
#
# Crear una función llamada `Calculo()` que acepte dos variables y retorne la suma y la resta absoluta de dichos valores, detallar si los valores no son numéricos.
#
# Nivel de dificultad:★★☆☆☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def Calculo(num1, num2):
#     if isinstance(num1, (int, float)) and isinstance(num2, (int, float)):
#         suma = num1 + num2
#         resta = abs(num1 - num2)
#         return suma, resta
#     else:
#         return 'Error, al menos una de las variables no es numerica.'
#
# print(Calculo(1,2.5))
#
#
# --->

# %%
#Solución

# %% [markdown]
# ### Ejercicio 6
#
# Crear una función que reciba una lista o tupla y sume todos sus valores. Validar que reciba específicamente estos valores.
#
# Nivel de dificultad:★★★☆☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def SumarLispla(ListaTupla):
#     if isinstance(ListaTupla, (list, tuple)):
#         suma = 0
#         for i in ListaTupla:
#             suma += i
#         return suma
#     else:
#         return 'Error, no se ha proporcionado una lista o tupla'
#
# lista= [1,2,3,4,5,6,7,8,9]
# tupla= (10,20,30,40,50,60,70,80,90)
# print(SumarLispla(lista))
# print(SumarLispla(tupla))
#
#
# --->

# %%
#Solución

# %% [markdown]
# ### Ejercicio 7
#
# Crear una función que reciba una cadena de texto e invierta su sentido.
#
# Nivel de dificultad:★★☆☆☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def Reverso(cadenatexto):
#     textocadena = ''
#     indice = len(cadenatexto)
#     while indice > 0:
#         textocadena += cadenatexto[indice - 1]
#         indice = indice - 1
#     return textocadena
# print(Reverso('1234abcd'))
#
#
# --->

# %%
#Solución

# %% [markdown]
# ### Ejercicio 8
#
# Crear una función que realice un clasificador de edades para personas de acuerdo a la siguiente tabla:
#
# |    Valor   | Clasificación |
# |:----------:|:-------------:|
# |    0 a 5   |      Bebe     |
# |   6 a 12   |      Niño     |
# |   13 a 17  |  Adolescente  |
# |  18 a  50  |     Adulto    |
# | Mayor a 50 |  Tercera Edad |
#
#
# Nivel de dificultad:★★☆☆☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def ClasificadorHumanoide(edad):
#     if isinstance(edad, (int, float)):
#         if edad >= 50:
#             print('Tercera Edad')
#         elif edad >= 18:
#             print('Adulto')
#         elif edad >= 13:
#             print('Adolescente')
#         elif edad >= 6:
#             print('Niño')
#         elif edad >= 0:
#             print('Bebe')
#         else:
#             print('Edad Incorrecta')
#     else:
#         print('Edad Incorrecta, no es numero')
# ClasificadorHumanoide(1)
#
#
# --->

# %%
#Solución

# %% [markdown]
# ### Ejercicio 9
#
# Crear una función que realice un contador de letras mayúsculas y minúsculas de un texto dado.
#
# Opciones de ejecución:
#
# 1.   Usar Diccionarios
# 2.   Usar listas
#
# Nivel de dificultad:★★★☆☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def MayusMinusDiccionario(s):
#     d={"MAYUS":0, "MINUS":0}
#     for c in s:
#         if c.isupper():
#            d["MAYUS"]+=1
#         elif c.islower():
#            d["MINUS"]+=1
#         else:
#            pass
#     print ("Cadena de texto original : ", s)
#     print ("Cantidad de MAYUSCULAS : ", d["MAYUS"])
#     print ("Candidad de minusculas : ", d["MINUS"])
#
# MayusMinusDiccionario('La EMPANADA y su gran amigo el Buñuelo')
#
# def MayusMinusLista(s):
#     MAYUS = []
#     minus = []
#     for c in s:
#         if c.isupper():
#            MAYUS.append(c)
#         elif c.islower():
#            minus.append(c)
#         else:
#            pass
#     print ("Cadena de texto original : ", s)
#     print ("Cantidad de MAYUSCULAS : ", len(MAYUS))
#     print ("Candidad de minusculas : ", len(minus))
#
# MayusMinusLista('La EMPANADA y su gran amigo el Buñuelo')
# --->

# %%
#Solución

# %% [markdown]
# ### Ejercicio 10
#
# Determinar si un numero ingresado es primo usando funciones.
#
# Nivel de dificultad:★★★★☆

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def SoyPrimo(n):
#     if (n==1):
#         return False
#     elif (n==2):
#         return True;
#     else:
#         for x in range(2,n):
#             if(n % x==0):
#                 return False
#         return True
# print(SoyPrimo(9))
#
# --->

# %%
#Solución

# %% [markdown]
# <p><a name="s7"></a></p>
#
# # **07. Clases y Objetos**
# [[Contenidos]](#contents)
#
#
# Python es un lenguaje de programación orientado a objetos. Casi todo en Python es un objeto, con sus propiedades y métodos. Una clase es como un constructor de objetos o un "molde" para crear objetos. Para crear una clase, use la palabra clave `class`.
#
#
# ```python
# class LaClase:
#     x = 123
# ```
# Crear un objeto corresponde a un dato(objeto) relacionado a una clase.
# A continuación crearemos un objeto llamado `dato` e imprime el valor de x:
# ```python
# dato = LaClase()
# print(dato.x)
# ```

# %% [markdown]
# ## **La función `__init__()`**
#
# Los ejemplos anteriores son clases y objetos en su forma más simple y no son realmente útiles en aplicaciones de la vida real.
#
# Para comprender el significado de las clases, debemos comprender la función incorporada `__init __()`. Todas las clases tienen una función llamada `__init __()`, que siempre se ejecuta cuando se inicia la clase.
# Se debe utilizar la función `__init __()` para asignar valores a las propiedades del objeto u otras operaciones que sean necesarias cuando se crea el objeto.
#
# Nota: La función `__init __()` se llama automáticamente cada vez que se usa la clase para crear un nuevo objeto. `__init __()` es un método reservado en las clases, es conocido como el método constructor en los conceptos de programación orientada a objetos (POO).
#
#
#
# ```python
# class Persona:
#   def __init__(self, nombre, edad):
#     self.nombre = nombre
#     self.edad = edad
#
# p1 = Persona("Bruce Wayne", 30)
#
# print(p1.nombre)
# print(p1.edad)
# ```

# %%
class Persona:
  def __init__(self, nombre, edad):
    self.nombre = nombre
    self.edad = edad

p1 = Persona("Bruce Wayne", 30)

print(p1.nombre)
print(p1.edad)

# %% [markdown]
# ## **Métodos de objetos**
#
# Los objetos también pueden contener métodos. Los métodos en los objetos son funciones que pertenecen al objeto. Creemos un método en la clase Persona:
#
#
# ```python
# class Persona:
#   def __init__(self, nombre, edad):
#     self.nombre = nombre
#     self.edad = edad
#
#   def UnaFuncion(self):
#     print("Hola, mi nombre es " + self.nombre)
#
# p1 = Persona("Clark Kent", 25)
# p1.UnaFuncion()
# ```
#
# Nota: El parámetro `self` es una referencia a la instancia actual de la clase y se usa para acceder a las variables que pertenecen a la clase.

# %%
class Persona:
  def __init__(self, nombre, edad):
    self.nombre = nombre
    self.edad = edad

  def UnaFuncion(self):
    print("Hola, mi nombre es " + self.nombre)

p1 = Persona("Clark Kent", 25)
p1.UnaFuncion()

# %% [markdown]
# ## **El parámetro `self`**
#
# El parámetro `self` es una referencia a la instancia actual de la clase y se usa para acceder a las variables que pertenecen a la clase. No tiene que llamarse `self`, puede llamarlo como quiera, pero tiene que ser el primer parámetro de cualquier función en la clase y se tiene por concenso el uso de la palabra `self`.
#
# A continuación cambiaremos la palabra `self` por otro valor y el ejercicio funciona perfectamente, pero se ve feo, se recomienda usar `self`.
#
#
# ```python
# class Persona:
#   def __init__(selfman, nombre, edad):
#     selfman.nombre = nombre
#     selfman.edad = edad
#
#   def OtraFuncion(manself):
#     print("Mi nombre es " + manself.name)
#
# p1 = Persona("Diana Prince", 30)
# p1.OtraFuncion()
# ```
#
# Las definiciones de clase no pueden estar vacías, pero si por alguna razón tiene una definición de clase sin contenido, coloque la declaración `pass` para evitar errores.
#
#
#
# ```python
# class Persona:
#   pass
# ```

# %%
class Persona:
  def __init__(selfman, nombre, edad):
    selfman.nombre = nombre
    selfman.edad = edad

  def OtraFuncion(manself):
    print("Mi nombre es " + manself.nombre)

p1 = Persona("Diana Prince", 30)
p1.OtraFuncion()

# %% [markdown]
# ## **Herencia de Python**
#
# La herencia nos permite definir una clase que hereda todos los métodos y propiedades de otra clase. La clase principal es la clase de la que se hereda, también llamada clase base. La clase hija es la clase que hereda de otra clase, también llamada clase derivada.
#
# ### **Crear una clase padre**
#
# Cualquier clase puede ser una clase principal, por lo que la sintaxis es la misma que la de crear cualquier otra clase, a continuación crearemos un ejemplo con una clase persona, con nombre, apellido y una método que imprima dichos datos.
#
#
#
# ```python
# class Persona:
#   def __init__(self, nombre, apellido):
#     self.nombre = nombre
#     self.apellido = apellido
#
#   def ImprimirNombre(self):
#     print(self.nombre, self.apellido)
#
# x = Persona("Hal", "Jordan")
# x.ImprimirNombre()
# ```
# ### **Crear una clase hija**
#
# Para crear una clase que herede la funcionalidad de otra clase, se debe pasar como parámetro la clase principal al crear la clase secundaria o hija. A continuación crearemos la clase llamada Estudiante la cual heredará las propiedades y métodos de la clase Persona.
#
# ```python
# class Estudiante(Persona):
#     pass
# ```
#
# Ahora la clase Estudiante tiene las mismas propiedades y métodos de la clase Persona.
# ```python
# x = Estudiante("Barry", "Allen")
# x.ImprimirNombre()
# ```

# %% [markdown]
# ## **Ejemplos de Clases**
#
# A continuación veremos ejemplos de código relacionado con clases.

# %%
#Crear una clase empleado y dos instancias.
class Empleado:
    pass
empleado1 = Empleado()
empleado2 = Empleado()

print(empleado1)
print(empleado2)

# %%
#Crear una clase empleado, dos instancias y crear dos atributos.
# %%time
class Empleado:
    pass
#No es necesario tener datos en la clase o propiedades para recibir atributos

empleado1 = Empleado()
empleado2 = Empleado()

empleado1.nombre = 'Bruce'
empleado1.apellido = 'Wayne'
empleado1.email = 'Bruce.Wayne@WayneEnterprises.com'
empleado1.salario = 5000000000

empleado2.nombre = 'Clark'
empleado2.apellido = 'Kent'
empleado2.email = 'Clark.Kent@DailyPlanet.com'
empleado2.salario = 5000
print('-----------------------------')
print(empleado1)
print(empleado2)
print('-----------------------------')
print('Empleado: ',empleado1.nombre, empleado1.apellido)
print('Email: ',empleado1.email)
print('Salario: {:,}'.format(empleado1.salario))
print('-----------------------------')
print('Empleado: ',empleado2.nombre, empleado2.apellido)
print('Email: ',empleado2.email)
print('Salario: {:,}'.format(empleado2.salario))
print('-----------------------------')

# %%
# %%time
class Empleado:
    def __init__(self, nombre, apellido, salario):
        self.nombre = nombre
        self.apellido = apellido
        self.salario = salario
        self.email = nombre + '.' + apellido + '@JusticeLeague.com'

empleado1 = Empleado('Bruce', 'Wayne', 5000000000)
empleado2 = Empleado('Clark', 'Kent', 5000)

print('-----------------------------')
print(empleado1)
print(empleado2)
print('-----------------------------')
print('Empleado: ',empleado1.nombre, empleado1.apellido)
print('Email: ',empleado1.email)
print('Salario: {:,}'.format(empleado1.salario))
print('-----------------------------')
print('Empleado: ',empleado2.nombre, empleado2.apellido)
print('Email: ',empleado2.email)
print('Salario: {:,}'.format(empleado2.salario))
print('-----------------------------')

# %%
# %%time
class Empleado:
    def __init__(self, nombre, apellido, salario):
        self.nombre = nombre
        self.apellido = apellido
        self.salario = salario
        self.email = nombre + '.' + apellido + '@JusticeLeague.com'

empleado1 = Empleado('Bruce', 'Wayne', 5000000000)
empleado2 = Empleado('Clark', 'Kent', 5000)

print('Imprimir el nombre de los empleados')
print(empleado1)
print(empleado2)
print('-----------------------------')
print('{} {}'.format(empleado1.nombre, empleado1.apellido))
print('{} {}'.format(empleado2.nombre, empleado2.apellido))
print('-----------------------------')

# %%
# %%time
class Empleado:
    def __init__(self, nombre, apellido, salario):
        self.nombre = nombre
        self.apellido = apellido
        self.salario = salario
        self.email = nombre + '.' + apellido + '@JusticeLeague.com'
    def NombreCompleto(self): #Solo necesitamos pasar 'self' como el objeto contenedor de la clase.
    #Si no utilizamos self nos detalla un error 
        return '{} {}'.format(self.nombre, self.apellido)

empleado1 = Empleado('Bruce', 'Wayne', 5000000000)
empleado2 = Empleado('Clark', 'Kent', 5000)

print('Imprimir el nombre de los empleados')
print(empleado1)
print(empleado2)
print('-----------------------------')
print(empleado1.NombreCompleto())
print(empleado2.NombreCompleto())
print('-----------------------------')

# %%
# %%time
class Empleado:
    def __init__(self, nombre, apellido, salario):
        self.nombre = nombre
        self.apellido = apellido
        self.salario = salario
        self.email = nombre + '.' + apellido + '@JusticeLeague.com'
#----------------------------QUITAMOS SELF-------------------------
    def NombreCompleto(self): #Solo necesitamos pasar 'self' como el objeto contenedor de la clase.
    #Si no utilizamos self nos detalla un error 
        return '{} {}'.format(self.nombre, self.apellido)

empleado1 = Empleado('Bruce', 'Wayne', 5000000000)
empleado2 = Empleado('Clark', 'Kent', 5000)

print('Imprimir el nombre de los empleados')
print(empleado1)
print(empleado2)
print('-----------------------------')
print(empleado1.NombreCompleto())
print(empleado2.NombreCompleto())
print('-----------------------------')

# %% [markdown]
# TypeError: NombreCompleto() takes 0 positional arguments but 1 was given
#
# Los métodos de clase y su instancia se pasa automaticamente, por eso detalla que '1 was given'.

# %%
# %%time
class Empleado:
    def __init__(self, nombre, apellido, salario):
        self.nombre = nombre
        self.apellido = apellido
        self.salario = salario
        self.email = nombre + '.' + apellido + '@JusticeLeague.com'
    def NombreCompleto(self):
        return '{} {}'.format(self.nombre, self.apellido)
#Llamando la clase
empleado1 = Empleado('Bruce', 'Wayne', 5000000000)
empleado2 = Empleado('Clark', 'Kent', 5000)

print('Imprimir el nombre de los empleados')
print(empleado1)
print(empleado2)
print('-----------------------------')
print(Empleado.NombreCompleto(empleado1)) #La clase no tiene conocimiento de sus datos, debo pasar el objeto con los valores.
print(Empleado.NombreCompleto(empleado2))
print('-----------------------------')

# %% [markdown]
# <p><a name="s8"></a></p>
#
# # **08. Ejercicios Parte 2, "La Venganza"**
# [[Contenidos]](#contents)
#
# Para todos los ejercicios a realizar a continuación, se deben detallar los argumentos de la función y explicar su elección en comentarios.
# Todos los ejercicios detallados a continuación ya fueron resueltos en clase,

# %% [markdown]
# ## **`Ejercicio 1`**
# <p>
#
# La ecuación de segundo grado:
#
# $ax² + bx + c = 0$
#
# puede tener una, dos o ninguna solución. Depende del valor del Discriminante:
#
# $D = b2 - 4ac$
#
# $D=0$
#
# Dos soluciones reales iguales. (Una solución.)
# Realice una función en el cual precise si una ecuación de segundo grado se puede solucionar en los reales y detallar las respuestas de la función.

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# import math as mt
# def Cuadratica(a, b, c):
#
#     discriminante = b**2 - 4 * a * c
#     if discriminante > 0:
#         x1 = (-b + mt.sqrt(discriminante))/2*a
#         x2 = (-b - mt.sqrt(discriminante))/2*a
#         resultado = 'Los resultados de la ecuacion son x1={:,.2f} , x2={:,.2f}'.format(x1,x2)
#     elif discriminante == 0:
#         x = -b/2*a
#         resultado = 'El resultado de la ecuacion es x={:,.2f}'.format(x)
#     else:
#         resultado = 'La ecuacion no tiene solucion en los reales.'
#     return resultado
#
#
# --->

# %%
#Solución

# %% [markdown]
# ## **`Ejercicio 2`**
# <p>
#
# Link necesita comprar flechas en el mercado Kokiri, cada flecha tiene un costo de 5 rupias, si compra más de 15 flechas valen 4 rupias cada una, si compra más de 45 quedan a 3 rupias cada una, pero si además de esto compra una poción roja, las flechas tienen un 20% de descuento sobre el monto 	total de la compra, si además compra una poción verde tendrá un descuento del 30%, pero si solo compra la poción verde tendrá un descuento del 10%.
#
# Realizar una función con la cual permita calcular el valor total de venta para la cantidad de flechas compradas y si compra o no pociones.
#
# ![Link](https://storage.googleapis.com/multi-static-content/thumbs/artage-io-thumb-1666557522561c2881979d96e74b0673.png)

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def CompraLink(flechas, pocionroja, pocionverde):
#     #flechas = Cantidad de flechas compradas
#     #pocionroja = Cantidad de pociones rojas compradas
#     #pocionverde = Cantidad de pociones verdes compradas
#     #Por Precisión
#     if flechas > 0 and flechas <= 15:
#         valorflechas = 5
#     elif flechas >= 16 and flechas <= 45:
#         valorflechas = 4
#     elif flechas >= 46:
#         valorflechas = 3
#     descuento = 1
#     if pocionroja > 0 and pocionverde == 0:
#         descuento = 0.8
#     if pocionverde > 0 and pocionroja == 0:
#         descuento = 0.9
#     if pocionverde > 0 and pocionroja > 0:
#         descuento  = 0.7
#
#     total = flechas*valorflechas*descuento
#     resultado = 'El total a pagar por {} flechas y {} pociones es: {:,.0f}'.format(flechas, (pocionroja+pocionverde), total)
#     return resultado
#
#
# --->

# %%
#Solución

# %% [markdown]
# ## **`Ejercicio 3`**
#
#
# El impuesto predial en el Municipio de Medellín se calcula de acuerdo al estrato socioeconómico y al avalúo catastral del inmueble. Realice una función que calcule el impuesto predial, basándose en el avalúo y el estrato, utilizando la siguiente tabla:
#
# Avalúo | Estrato 1 | Estrato 2 | Estrato 3 | Estrato 4 | Estrato 5 | Estrato 6
# ---|---|---|---|---|---|---
# De 0 a 5.000.000 | 6 Por Mil | 7 Por Mil | 8 Por Mil | 9 Por Mil | 10 Por Mil | 11 Por Mil
# De 5.000.001 a 50.000.000 | 7 Por Mil | 8 Por Mil | 9 Por Mil | 10 Por Mil | 11 Por Mil | 12 Por Mil
# De 50.000.001 a 100000000 | 8 Por Mil | 9 Por Mil | 10 Por Mil | 11 Por Mil | 12 Por Mil | 13 Por Mil
# De 100.000.001 a 300000000 | 9 Por Mil | 10 Por Mil | 11 Por Mil | 12 Por Mil | 13 Por Mil | 14 Por Mil
# De 300.000.001 en adelante | 10 Por Mil | 11 Por Mil | 12 Por Mil | 13 Por Mil | 14 Por Mil | 15 Por Mil

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def ImpuestoMed(avaluo, estrato):
#     #Por extensión
#     if avaluo > 300000000:
#         if estrato > 5:
#             mil = 15
#         elif estrato > 4:
#             mil = 14
#         elif estrato > 3:
#             mil = 13
#         elif estrato > 2:
#             mil = 12
#         elif estrato > 1:
#             mil = 11
#         else:
#             mil = 10
#     elif avaluo > 100000000:
#         if estrato > 5:
#             mil = 14
#         elif estrato > 4:
#             mil = 13
#         elif estrato > 3:
#             mil = 12
#         elif estrato > 2:
#             mil = 11
#         elif estrato > 1:
#             mil = 10
#         else:
#             mil = 9
#     elif avaluo > 50000000:
#         if estrato > 5:
#             mil = 13
#         elif estrato > 4:
#             mil = 12
#         elif estrato > 3:
#             mil = 11
#         elif estrato > 2:
#             mil = 10
#         elif estrato > 1:
#             mil = 9
#         else:
#             mil = 8
#     elif avaluo > 5000000:
#         if estrato > 5:
#             mil = 12
#         elif estrato > 4:
#             mil = 11
#         elif estrato > 3:
#             mil = 10
#         elif estrato > 2:
#             mil = 9
#         elif estrato > 1:
#             mil = 8
#         else:
#             mil = 7
#     else:
#         if estrato > 5:
#             mil = 11
#         elif estrato > 4:
#             mil = 10
#         elif estrato > 3:
#             mil = 9
#         elif estrato > 2:
#             mil = 9
#         elif estrato > 1:
#             mil = 7
#         else:
#             mil = 6
#
#     total = (avaluo / 1000) * mil
#     return 'El impuesto para una construcción con avalúo de: {:,.0f} y estrato {} es de: {:,.0f}'.format(avaluo, estrato, total)
#
# --->

# %%
#Solución

# %% [markdown]
# ## **`Ejercicio 4`**
#
# En teoría de números, el [último teorema de Fermat](https://es.wikipedia.org/wiki/%C3%9Altimo_teorema_de_Fermat), o teorema de Fermat-Wiles, es uno de los teoremas más famosos en la historia de las matemáticas. Utilizando la notación moderna, se puede enunciar de la siguiente manera:
# Si $n$ es un número entero mayor o igual que $3$, entonces no existen números enteros positivos $x$, $y$ y $z$, tales que se cumpla la igualdad:
#
# $x^n + y^n = z^n$
#
# Este teorema fue conjeturado por Pierre de Fermat en 1637, pero no fue demostrado hasta 1995 por Andrew Wiles ayudado por el matemático Richard Taylor. La búsqueda de una demostración estimuló el desarrollo de la teoría algebraica de números en el siglo XIX y la demostración del teorema de la modularidad en el siglo XX.
#
# Realizar una función el cual pruebe que la conjetura de Fermat no tiene solución para 1000 iteraciones y detalle el menor valor de la ecuación, utilice números aleatorios para detallar el presente ejercicio.

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
#
# import random as rnd
# def PruebaFermat():
#     x, y, z = [], [], []
#     n = []
#     #Poblamos los vectores
#     for i in range(1000):
#         x.append(i+1)
#         y.append(i+1)
#         z.append(i+1)
#         n.append(i+1)
#
#     #Vamos a crear un ciclo para los valores iterando el largo de un vector
#     f = len(x)
#     for k in range(f):
#         #obtenemos los valores
#         x1 = rnd.choice(x)
#         y1 = rnd.choice(y)
#         z1 = rnd.choice(z)
#         n1 = rnd.choice(n)
#         #debo eliminar esos valores de los vectores
#         x.remove(x1)
#         y.remove(y1)
#         z.remove(z1)
#         n.remove(n1)
#         #Valido la ecuacion de don Fermat
#         if (x1**n1 + y1**n1) == z1**n1:
#             resultado = True
#         else:
#             resultado = False
#     if resultado:
#         return 'Hemos demostrado lo imposible: Fermat no tenia razón'
#     else:
#         return 'Fermat y Wiles tienen razón, no hay valores que cumplan la ecuacion'
# --->

# %%
#Solución

# %% [markdown]
# ## **`Ejercicio 5`**
# <p>
# Elabore una función que le permita saber el tipo de triangulo, ingresando los lados.
# <br><br>
#
#
# <img alt="Triangulos1" height="300px" src="https://s1.significados.com/foto/tipos-de-triangulos-63_bg.jpg" align="left" hspace="10px" vspace="0px">
#
# <img alt="Triangulos2" height="270px" src="https://es-static.z-dn.net/files/d5d/3c75a97024bd9d95c9ab7adbdf3a77b6.jpg" align="center" hspace="10px" vspace="0px">

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# lados = []
# angulos = []
# lados.append(int(input('Ingresar Lado a: ')))
# lados.append(int(input('Ingresar Lado b: ')))
# lados.append(int(input('Ingresar Lado c: ')))
# angulos.append(int(input('Ingresar Angulo α alfa: ')))
# angulos.append(int(input('Ingresar Angulo β beta: ')))
# angulos.append(int(input('Ingresar Angulo θ theta: ')))
#
# def Triangulos(_lados, _angulos):
#     texto = 'Datos no corresponden a un triangulo'
#     #Equilatero - todos iguales
#     if lados[0] == lados[1] and lados[1] == lados[2]:
#         if angulos[0] == angulos[1] and angulos[1] == angulos[2]:
#             texto = 'Triangulo acutangulos equilatero'
#     #Isoceles 2 iguales de ambos
#     elif lados[0] == lados[1] or lados[0] == lados[2] or lados[1] == lados[2]:
#         if angulos[0] == angulos[1] or angulos[0] == angulos[2] or angulos[1] == angulos[2]:
#             texto = 'Triangulo acutangulos isoceles'
#             if 90 in angulos:
#                 texto = 'Triangulo rectangulo isoceles'
#             if angulos[0] > 90 or  angulos[1] > 90 or angulos[2] > 90:
#                 texto = 'Triangulo obtusangulo isoceles'
#     #Escaleno todos diferentes
#     elif lados[0] != lados[1] or lados[0] != lados[2] or lados[1] != lados[2]:
#         if angulos[0] != angulos[1] or angulos[0] != angulos[2] or angulos[1] != angulos[2]:
#             if angulos[0] < 90 or angulos[1] < 90 or angulos[2] < 90:
#                 texto = 'Triangulo acutangulo escaleno'
#             if 90 in angulos:
#                 texto = 'Triangulo rectangulo escaleno'
#             if angulos[0] > 90 or  angulos[1] > 90 or angulos[2] > 90:
#                 texto = 'Triangulo obtusangulo escaleno'
#     return texto
#
# --->

# %%
#Solución

# %% [markdown]
# ## **`Ejercicio 6`**
#
# En la Tierra Media, lugar del Señor de los Anillos existe un lugar llamado Bree, en dicho lugar hay una taberna llamada The Prancing Pony, la cual establece los precios de acuerdo a la raza de la siguiente manera: los Elfos tienen un descuento del 4%, los Enanos tienen un descuento del 8%, los humanos tienen un descuento del 15%, los Hobbits tienen un descuento del 20%, los Magos tienen un descuento del 30% y los Orcos tienen un sobre cobro del 5%. Elabore una función para determinar cuánto debe pagar alguien de cualquier raza si compra cualquier cantidad de cervezas a 4 monedas de plata cada una.
#
# [Bree](https://3rin.gs/#0.1156006,0.2343750,0.2546387,0.3031616,l,)
#
# <img alt="Triangulos1" height="400px" src="https://i.pinimg.com/originals/e6/f9/8a/e6f98a86950fa44d0569cee359f6fa1d.jpg" align="left" hspace="10px" vspace="0px">

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def PrancingPonyVentas(_raza, _cervezas, _vendedor):
#     valor = 4
#     if raza == "Elfos":
#         descuento = 0.96
#     elif raza == "Enanos":
#         descuento = 0.92
#     elif raza == "Humanos":
#         descuento = 0.85
#     elif raza == "Hobbits":
#         descuento = 0.8
#     elif raza == "Magos":
#         descuento = 0.7
#     else:
#         descuento = 1.05
#     if descuento > 1:
#         estado = "Sobrecosto"
#     else:
#         estado = "Descuento"
#     total = cervezas * valor * descuento
#     return total
# PrancingPonyVentas()
#
# --->

# %%
#Solución
raza = "Elfos" #@param ["Elfos", "Enanos", "Humanos", "Hobbits", "Magos", "Orcos"]
cervezas = 20 #@param {type:"integer"}
vendedor = "Julian" #@param {type:"string"}

# %%
#ContinuarSolución

# %% [markdown]
# ## **`Ejercicio 7`**
#
# El costo de las llamadas telefónicas mediante celular en Colombia depende del operador origen y el operador destino y la cantidad de minutos hablados. En la siguiente tabla se presenta el coste de las llamadas por minuto entre operadores. Determine el costo de cualquier llamada mediante la implementación de una función.
#
# Operador Origen | Operador Destino | Valor Minuto
# ---|---|---
# Tigo | Tigo | \$ 5
# Tigo | Claro | \$ 7
# Tigo | Movistar | \$ 6
# Claro | Claro | \$ 6
# Claro | Tigo | \$ 7
# Claro | Movistar | \$ 8
# Movistar | Movistar | \$ 5
# Movistar | Claro | \$ 6
# Movistar | Tigo | \$ 6

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def CelularesLocos(origen, destino, minutos):
#     origen = origen.lower()
#     destino = destino.lower()
#     error = '_'
#     valor = 0
#     if origen == 'tigo':
#         if destino == 'tigo':
#             valor = 5
#         elif destino == 'claro':
#             valor = 7
#         elif destino == 'movistar':
#             valor = 6
#         else:
#             error = 'Error de destino'
#     elif origen == 'claro':
#         if destino == 'claro':
#             valor = 6
#         elif destino == 'tigo':
#             valor = 7
#         elif destino == 'movistar':
#             valor = 8
#         else:
#             error = 'Error de destino'
#     elif origen == 'movistar':
#         if destino == 'movistar':
#             valor = 5
#         elif destino == 'tigo':
#             valor = 6
#         elif destino == 'claro':
#             valor = 6
#         else:
#             error = 'Error de destino'
#             valor = 0
#     else:
#         error = 'Error de origen'
#     total = minutos*valor
#     if len(error) > 1:
#         return error
#     else:
#         return 'El valor total de la llamada es: {:,.2f}'.format(total)
# print(CelularesLocos('Tigo', 'Clarso', 60))
#
# --->

# %%
#Solución

# %% [markdown]
# ## **`Ejercicio 8`**
#
# El costo de los servicios públicos domiciliarios depende del consumo y del estrato donde se encuentre ubicada la vivienda. Todos los servicios tienen un consumo mínimo determinado en la tabla 1 y un cobro por unidad de medida definido en la tabla 2, de acuerdo con datos leídos y correspondientes con el estrato, la energía, el agua y el acueducto. Determinar el valor a pagar por el total de servicios públicos domiciliarios mediante el uso de funciones.
#
# <center> Tabla 1 </center>
#
# Consumo Mínimo | Estrato 1 o 2 | Estrato 3 o 4 | Estrato 5 o 6
# ---|---|---|---
# Energía | 500 | 600 | 700
# Agua | 300 | 400 | 500
# Acueducto | 50 | 70 | 90
#
# <br>
# <center> Tabla 2 </center>
#
# Cobro por Unidad | Estrato 1 o 2 | Estrato 3 o 4 | Estrato 5 o 6 | Unidad de Medida
# ---|---|---|---|---
# Energía | \$34 | \$55 | \$77 | KW/h
# Agua | \$22 | \$39 | \$42 | m³
# Acueducto | \$5 | \$12 | \$13 | m³

# %% [markdown]
# Hacer doble click <b>aquí</b> para ver la solución:
#
# <!-- Respuesta:
#
# def ServiPubli(estrato, energia, agua, acueducto):
#     error = False
#     if estrato > 4:
#         if energia > 700:
#             pagoenergia = energia * 77
#         else:
#             pagoenergia = 700 * 77
#
#         if agua > 500:
#             pagoagua = agua * 42
#         else:
#             pagoagua = 500 * 42
#
#         if acueducto > 90:
#             pagoacueducto = acueducto * 13
#         else:
#             pagoacueducto = 90 * 13
#     elif estrato > 2:
#         if energia > 600:
#             pagoenergia = energia * 55
#         else:
#             pagoenergia = 600 * 55
#         if agua > 400:
#             pagoagua = agua * 39
#         else:
#             pagoagua = 400 * 39
#         if acueducto > 70:
#             pagoacueducto = acueducto * 12
#         else:
#             pagoacueducto = 70 * 12
#     elif estrato > 0:
#         if energia > 500:
#             pagoenergia = energia * 34
#         else:
#             pagoenergia = 500 * 34
#         if agua > 300:
#             pagoagua = agua * 22
#         else:
#             pagoagua = 300 * 22
#         if acueducto > 50:
#             pagoacueducto = acueducto * 5
#         else:
#             pagoacueducto = 50 * 5
#     else:
#         error = True
#         textrror = 'Error en el valor del estrato'
#
#     if error:
#         total = 'ERROR' + ' ' + textrror
#     else:
#         total = pagoacueducto+pagoagua+pagoenergia
#
#     return 'El valor total a pagar es {}'.format(total)
#
# --->

# %%
#Solución

# %% [markdown]
# ---
# ###**Ejercicios para validar el conocimiento**
# ---

# %% [markdown]
# ## **`Ejercicio 9`**
#
# Batman compra sus artefactos y dispositivos para combatir el crimen mediante una empresa subsidiaria de Wayne Enterprises, en la cual deben hacer pedidos muy grandes y variados para evitar que identifiquen que Bruce Wayne es Batman. Debido a esto Bruce Wayne necesita que usted, un magnifico estudiante de Posgrados de la IUDigital, realice una función en mediante la cual calcule la cantidad de artefactos y dispositivos que necesita pedir el Señor Lucius Fox mediante dicha empresa subsidiaria utilizando valores aleatorios para no delatar al señor Wayne mediante la siguiente tabla.
#
# <center>Ítem</center>|<center>Mes</center>|<center>Tipo</center>|<center>Aleatorio Nivel Inferior Pedido</center>|<center>Aleatorio Nivel Superior Pedido</center>
# ---|---|---|---|---
# <center>Batarang</center>|<center>Par</center>|<center>Artefacto</center>|<center>1500</center>|<center>3500</center>
# <center>Batarang</center>|<center>Impar</center>|<center>Artefacto</center>|<center>2500</center>|<center>4500</center>
# <center>Grappling Gun</center>|<center>Par</center>|<center>Dispositivo</center>|<center>15</center>|<center>30</center>
# <center>Grappling Gun</center>|<center>Impar</center>|<center>Dispositivo</center>|<center>10</center>|<center>20</center>
# <center>Ultrasonic Bat Beacon</center>|<center>Par</center>|<center>Dispositivo</center>|<center>5</center>|<center>7</center>
# <center>Ultrasonic Bat Beacon</center>|<center>Impar</center>|<center>Dispositivo</center>|<center>9</center>|<center>11</center>
# <center>Gauntlets</center>|<center>Par</center>|<center>Artefacto</center>|<center>250</center>|<center>300</center>
# <center>Gauntlets</center>|<center>Impar</center>|<center>Artefacto</center>|<center>400</center>|<center>450</center>
#
# <br>
# <center>
# <img alt="Wayne" height="200px" src="https://static.wikia.nocookie.net/batman/images/1/1d/Wayne-enterprises-logo.png/revision/latest?cb=20150208155844&path-prefix=es" align="center" hspace="10px" vspace="0px"></center>

# %%
#Solución

# %% [markdown]
# ## **`Ejercicio 10`**
#
# Desarrolle una función que calcule el valor de las cuotas a pagar por la compra de televisores en [Flamingo](https://www.flamingo.com.co/), esta se calcula dividiendo el valor del televisor por el número de cuotas seleccionado y se agrega el valor porcentual(del valor total) establecido de acuerdo con la siguiente tabla
#
# <table>
# <thead>
#   <tr>
#     <th rowspan="2">Valor Televisor</th>
#     <th colspan="5">Valor porcentual por número de cuotas</th>
#   </tr>
#   <tr>
#     <td>1 a 6 </td>
#     <td>7 a 10 </td>
#     <td>11 a 18 </td>
#     <td>19 a 24 </td>
#     <td>25 a 48 </td>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>Entre $ 500.000 y $ 1.000.000</td>
#     <td>2%</td>
#     <td>4%</td>
#     <td>6%</td>
#     <td>8%</td>
#     <td>10%</td>
#   </tr>
#   <tr>
#     <td>Entre $ 1.000.001 y $&nbsp;&nbsp;&nbsp;1.500.000</td>
#     <td>3%</td>
#     <td>5%</td>
#     <td>7%</td>
#     <td>9%</td>
#     <td>11%</td>
#   </tr>
#   <tr>
#     <td>Entre $ 1.500.001 y $&nbsp;&nbsp;&nbsp;2.000.000</td>
#     <td>4%</td>
#     <td>6%</td>
#     <td>8%</td>
#     <td>10%</td>
#     <td>12%</td>
#   </tr>
#   <tr>
#     <td>Entre $ 2.000.001 y $&nbsp;&nbsp;&nbsp;3.000.000</td>
#     <td>5%</td>
#     <td>7%</td>
#     <td>9%</td>
#     <td>11%</td>
#     <td>13%</td>
#   </tr>
#   <tr>
#     <td>Más de $ 3.000.000</td>
#     <td>6%</td>
#     <td>8%</td>
#     <td>10%</td>
#     <td>12%</td>
#     <td>14%</td>
#   </tr>
# </tbody>
# </table>
#
# <br>
# <center>
# <img alt="Wayne" height="100px" src="https://www.flamingo.com.co/arquivos/logoFlamingo-te-cuida.png?v=637280176629870000" align="center" hspace="10px" vspace="0px"></center>

# %%
#Solución

# %% [markdown]
# ## **`Ejercicio 11`**
#
# Elabore un función que dé solución a la siguiente expresión algebraica para $x$ en donde $1$ es igual al cociente entre un paraboloide hiperbólico y un hiperboloide de una hoja, lea las variables y constantes que sean necesarias.
#
# $$1=\frac{\frac{x^2-y^2}{a^2-b^2}-cz}{\frac{x^2}{a^2}+\frac{y^2}{b^2}-\frac{z^2}{c^2}}$$

# %%
#Solución

# %% [markdown]
# ## **`Ejercicio 12`**
#
# Crear una lista llamada `NumAleatorios = []` en la cual usando un ciclo `For` se registren mil numeros aleatorios entre `100` y `999`. Elabore una función que reciba la lista `NumAleatorios` y retorne una cadena de texto en donde detalle los sigueintes procedimientos realizados:
#
# 1.	Determinar el menor número de la lista.
# 2.	Determinar el promedio de los números múltiplos de 3.
# 3.	Determinar cuántos números terminan en 2 y 8
# 4.	Determinar el promedio de todos los números.

# %% [markdown]
# <p><a name="contents"></a></p>
#
# # **Final del Contenido Sesión 3**
# ## **Gracias por participar, nos vemos en la sesión 4**
